# %%
# Dependencies
import tweepy
import json
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib import style

consumer_key = "uAtaKczfyecS0LzHDnBXRNlZC"
consumer_secret = "CNcjkxOJvZuUL1y75RUbYnZZAmlgueOw6b3pnXv139kd2Uai1y"
access_token = "942074532487159809-HDxyhszV9OiqMDkppa4CVLBpetypuC2"
access_token_secret = "x9dKveUyT691PHOldQMTuLiVq3fcmdTp4TIVysPlgyVpx"

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Target Search Term
#"@BBC", "@CBS", "@CNN","@FoxNews", "@nytimes")
            
# Target Account
target_BBC = "@BBC"

# Counter
counter = 1

# Variables for holding sentiments
sentiments_bbc = []

# Variable for max_id
oldest_tweet = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_BBC, max_id = oldest_tweet)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        tweets_ago = counter
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_bbc.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter += 1

# %%
sentiments_bbc_pd = pd.DataFrame.from_dict(sentiments_bbc)
sentiments_bbc_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.5707  Mon Jun 04 19:03:02 +0000 2018     0.178    0.822       0.0
# 1   -0.4767  Mon Jun 04 18:31:05 +0000 2018     0.171    0.829       0.0
# 2   -0.5859  Mon Jun 04 18:02:05 +0000 2018     0.231    0.769       0.0
# 3    0.0000  Mon Jun 04 17:01:13 +0000 2018     0.000    1.000       0.0
# 4    0.0000  Mon Jun 04 16:01:04 +0000 2018     0.000    1.000       0.0
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
print(len(sentiments_bbc_pd))
# Out:
# 100

# %%
# Target Account
target_CBS = "@CBS"

# Counter
counter1 = 1

# Variables for holding sentiments
sentiments_cbs = []

# Variable for max_id
oldest_tweet1 = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_CBS, max_id = oldest_tweet1)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results1 = analyzer.polarity_scores(tweet["text"])
        compound1 = results1["compound"]
        pos1 = results1["pos"]
        neu1 = results1["neu"]
        neg1 = results1["neg"]
        tweets_ago1 = counter1
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet1 = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_cbs.append({"Date": tweet["created_at"], 
                           "Compound": compound1,
                           "Positive": pos1,
                           "Negative": neg1,
                           "Neutral": neu1,
                           "Tweets Ago": counter1})
        
        # Add to counter 
        counter1 += 1

# %%
print(len(sentiments_cbs))
# Out:
# 20

# %%
sentiments_cbs_pd = pd.DataFrame.from_dict(sentiments_cbs)
sentiments_cbs_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Mon Jun 04 17:00:00 +0000 2018     0.000    1.000     0.000
# 1   -0.3903  Fri Jun 01 17:39:17 +0000 2018     0.131    0.807     0.062
# 2    0.8442  Fri Jun 01 17:00:03 +0000 2018     0.000    0.664     0.336
# 3    0.8932  Thu May 31 23:50:00 +0000 2018     0.000    0.545     0.455
# 4    0.4926  Wed May 30 15:07:34 +0000 2018     0.000    0.849     0.151
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
target_CNN = "@CNN"

# Counter
counter2 = 1

# Variables for holding sentiments
sentiments_cnn = []

# Variable for max_id
oldest_tweet2 = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_CNN, max_id = oldest_tweet2)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results2 = analyzer.polarity_scores(tweet["text"])
        compound2 = results2["compound"]
        pos2 = results2["pos"]
        neu2 = results2["neu"]
        neg2 = results2["neg"]
        tweets_ago2 = counter2
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet2 = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_cnn.append({"Date": tweet["created_at"], 
                           "Compound": compound2,
                           "Positive": pos2,
                           "Negative": neg2,
                           "Neutral": neu2,
                           "Tweets Ago": counter2})
        
        # Add to counter 
        counter2 += 1

# %%
sentiments_cnn_pd = pd.DataFrame.from_dict(sentiments_cnn)
sentiments_cnn_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0     0.000  Tue Jun 05 00:16:31 +0000 2018     0.000    1.000       0.0
# 1     0.000  Tue Jun 05 00:15:22 +0000 2018     0.000    1.000       0.0
# 2    -0.891  Tue Jun 05 00:06:05 +0000 2018     0.371    0.629       0.0
# 3     0.000  Tue Jun 05 00:01:10 +0000 2018     0.000    1.000       0.0
# 4     0.000  Mon Jun 04 23:56:05 +0000 2018     0.000    1.000       0.0
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
target_fox = "@FoxNews"

# Counter
counter3 = 1

# Variables for holding sentiments
sentiments_fox = []

# Variable for max_id
oldest_tweet3 = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_fox, max_id = oldest_tweet3)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results3 = analyzer.polarity_scores(tweet["text"])
        compound3 = results3["compound"]
        pos3 = results3["pos"]
        neu3 = results3["neu"]
        neg3 = results3["neg"]
        tweets_ago3 = counter3
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet3 = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_fox.append({"Date": tweet["created_at"], 
                           "Compound": compound3,
                           "Positive": pos3,
                           "Negative": neg3,
                           "Neutral": neu3,
                           "Tweets Ago": counter3})
        
        # Add to counter 
        counter3 += 1

# %%
sentiments_fox_pd = pd.DataFrame.from_dict(sentiments_fox)
sentiments_fox_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.0516  Tue Jun 05 00:23:04 +0000 2018     0.066    0.934     0.000
# 1   -0.5423  Tue Jun 05 00:14:00 +0000 2018     0.226    0.774     0.000
# 2    0.0000  Tue Jun 05 00:11:29 +0000 2018     0.000    1.000     0.000
# 3    0.4404  Tue Jun 05 00:08:53 +0000 2018     0.000    0.868     0.132
# 4   -0.4939  Tue Jun 05 00:05:42 +0000 2018     0.138    0.862     0.000
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
target_nyt = "@nytimes"

# Counter
counter4 = 1

# Variables for holding sentiments
sentiments_nyt = []

# Variable for max_id
oldest_tweet4 = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_nyt, max_id = oldest_tweet4)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results4 = analyzer.polarity_scores(tweet["text"])
        compound4 = results4["compound"]
        pos4 = results4["pos"]
        neu4 = results4["neu"]
        neg4 = results4["neg"]
        tweets_ago4 = counter4
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet4 = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_nyt.append({"Date": tweet["created_at"], 
                           "Compound": compound4,
                           "Positive": pos4,
                           "Negative": neg4,
                           "Neutral": neu4,
                           "Tweets Ago": counter4})
        
        # Add to counter 
        counter4 += 1

# %%
sentiments_nyt_pd = pd.DataFrame.from_dict(sentiments_nyt)
sentiments_nyt_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.5574  Tue Jun 05 00:17:02 +0000 2018     0.159    0.841     0.000
# 1    0.7351  Tue Jun 05 00:03:05 +0000 2018     0.000    0.617     0.383
# 2    0.0000  Mon Jun 04 23:53:03 +0000 2018     0.000    1.000     0.000
# 3    0.5994  Mon Jun 04 23:47:01 +0000 2018     0.000    0.804     0.196
# 4    0.0000  Mon Jun 04 23:36:01 +0000 2018     0.000    1.000     0.000
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
# Cloudiness (%) vs. Latitude
y = sentiments_bbc_pd["Compound"]
x = sentiments_bbc_pd["Tweets Ago"]

y1 = sentiments_cbs_pd["Compound"]
x1 = sentiments_cbs_pd["Tweets Ago"]

y2 = sentiments_cnn_pd["Compound"]
x2 = sentiments_cnn_pd["Tweets Ago"]

y3 = sentiments_fox_pd["Compound"]
x3 = sentiments_fox_pd["Tweets Ago"]

y4 = sentiments_nyt_pd["Compound"]
x4 = sentiments_nyt_pd["Tweets Ago"]

plt.scatter(x, y, linewidths=1, color='b', alpha=0.75, label="BBC")
plt.scatter(x1, y1, linewidths=1, color='m', alpha=0.75, label="CBS")
plt.scatter(x2, y2, linewidths=1, color='r', alpha=0.75, label="CNN")
plt.scatter(x3, y3, linewidths=1, color='g', alpha=0.75, label="Fox News")
plt.scatter(x4, y4, linewidths=1, color='c', alpha=0.75, label="NY Times")
plt.title ("Sentiment Analysis of Tweets 6/04/18")
plt.xlabel("Tweets Ago")
plt.ylabel("Compound")
plt.xlim([0, 100])
plt.ylim([-1, 1])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("Sentiment Analysis of Tweets 6/04/18")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
sentiments_bbc_pd = {
        "User": target_BBC,
        "Compound": np.mean(compound),
        "Positive": np.mean(pos),
        "Neutral": np.mean(neg),
        "Negative": np.mean(neu),
        #"Tweets Ago": (counter)
    }

sentiments_cbs_pd = {
        "User": target_CBS,
        "Compound": np.mean(compound1),
        "Positive": np.mean(pos1),
        "Neutral": np.mean(neg1),
        "Negative": np.mean(neu1),
        #"Tweets Ago": (counter)
    }

sentiments_cnn_pd = {
        "User": target_CNN,
        "Compound": np.mean(compound2),
        "Positive": np.mean(pos2),
        "Neutral": np.mean(neg2),
        "Negative": np.mean(neu2),
        #"Tweets Ago": (counter)
    }

sentiments_fox_pd = {
        "User": target_fox,
        "Compound": np.mean(compound3),
        "Positive": np.mean(pos3),
        "Neutral": np.mean(neg3),
        "Negative": np.mean(neu3),
        #"Tweets Ago": (counter)
    }

sentiments_nyt_pd = {
        "User": target_nyt,
        "Compound": np.mean(compound4),
        "Positive": np.mean(pos4),
        "Neutral": np.mean(neg4),
        "Negative": np.mean(neu4),
        #"Tweets Ago": (counter)
    }

# %%
#Averages
print(sentiments_bbc_pd)
print(sentiments_cbs_pd)
print(sentiments_cnn_pd)
print(sentiments_fox_pd)
print(sentiments_nyt_pd)
# Out:
# {'User': '@BBC', 'Compound': 0.3612, 'Positive': 0.172, 'Neutral': 0.0, 'Negative': 0.828}
# {'User': '@CBS', 'Compound': 0.0, 'Positive': 0.0, 'Neutral': 0.0, 'Negative': 1.0}
# {'User': '@CNN', 'Compound': -0.4932, 'Positive': 0.0, 'Neutral': 0.189, 'Negative': 0.811}
# {'User': '@FoxNews', 'Compound': -0.4215, 'Positive': 0.0, 'Neutral': 0.219, 'Negative': 0.781}
# {'User': '@nytimes', 'Compound': -0.6597, 'Positive': 0.0, 'Neutral': 0.423, 'Negative': 0.577}

# %%
results_list = pd.DataFrame([sentiments_bbc_pd, sentiments_cbs_pd, sentiments_cnn_pd, sentiments_fox_pd, sentiments_nyt_pd])

# %%
news_df = pd.DataFrame(results_list).set_index("User").round(3)
news_df
# Out:
#           Compound  Negative  Neutral  Positive
# User
# @BBC         0.361     0.828    0.000     0.172
# @CBS         0.000     1.000    0.000     0.000
# @CNN        -0.493     0.811    0.189     0.000
# @FoxNews    -0.422     0.781    0.219     0.000
# @nytimes    -0.660     0.577    0.423     0.000

# %%
news_df = news_df.reset_index()
print(list(news_df))
# Out:
# ['User', 'Compound', 'Negative', 'Neutral', 'Positive']

# %%
plt.bar((sentiments_bbc_pd['User']), (sentiments_bbc_pd['Compound']), alpha=0.5, align="edge", color='b', label="BBC")
plt.bar((sentiments_cbs_pd['User']), (sentiments_cbs_pd['Compound']), alpha=0.5, align="edge", color='m', label="CBS")
plt.bar((sentiments_cnn_pd['User']), (sentiments_cnn_pd['Compound']), alpha=0.5, align="edge", color='r', label="CNN")
plt.bar((sentiments_fox_pd['User']), (sentiments_fox_pd['Compound']), alpha=0.5, align="edge", color='g', label="Fox News")
plt.bar((sentiments_nyt_pd['User']), (sentiments_nyt_pd['Compound']), alpha=0.5, align="edge", color='c', label="NY Times")

plt.title("Overall Media Sentiment Analysis on Twitter on 6/04/2018")

plt.ylabel("Twitter Polarity")
plt.xlim([0, 5])
plt.ylim([-1, 1])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("Overall Media Sentiment Analysis on Twitter on 6/04/2018")
plt.show()
